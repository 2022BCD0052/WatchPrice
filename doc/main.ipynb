# %%
import pandas as pd

# %%
df = pd.read_csv('/home/yogeshsaini/ml Projects/WatchPrice/data/smartwatches.csv')

# %%
df.head()
# Out:
#    index       Brand  Current Price  Original Price  Discount Percentage  \
# 0      0       noise        82990.0         89900.0             7.686318
# 1      1  fire-boltt         3799.0         16999.0            77.651627
# 2      2        boat         1999.0          7990.0            74.981227
# 3      3  fire-boltt         1799.0         19999.0            91.004550
# 4      4       noise         1599.0          4999.0            68.013603
#
#    Rating  Number OF Ratings                              Model Name  \
# 0     4.0               65.0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk
# 1     4.3            20788.0                                  BSW046
# 2     3.8            21724.0                               Wave Call
# 3     4.3            13244.0                                  BSW053
# 4     4.1            13901.0  Wrb-sw-colorfitpulsegobuzz-std-blk_blk
#
#   Dial Shape Strap Color Strap Material Touchscreen  Battery Life (Days)  \
# ...

# %%
# Remove the last two columns using drop
df = df.drop(df.columns[-2:], axis=1)

# %%
# Unnamed : 0 (remove)
df.shape
df.head()
# Out:
#    index  Unnamed: 0       Brand  Current Price  Original Price  \
# 0      0           0       noise        82990.0         89900.0
# 1      1           1  fire-boltt         3799.0         16999.0
# 2      2           2        boat         1999.0          7990.0
# 3      3           3  fire-boltt         1799.0         19999.0
# 4      4           4       noise         1599.0          4999.0
#
#    Discount Percentage  Rating  Number OF Ratings  \
# 0             7.686318     4.0               65.0
# 1            77.651627     4.3            20788.0
# 2            74.981227     3.8            21724.0
# 3            91.004550     4.3            13244.0
# 4            68.013603     4.1            13901.0
#
#                                Model Name Dial Shape Strap Color  \
# 0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk        NaN         NaN
# 1                                  BSW046        NaN         NaN
# 2                               Wave Call        NaN         NaN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
# Unnamed : 0 (remove)
df.shape
# Out:
# (450, 15)

# %%
train_def = df.sample(frac=0.8, random_state=42)

# %%
train_def = train_def.reset_index(drop=True)

# %%
train_def = train_def.reset_index(drop=True)

# %%
test_df = df.drop(train_def.index)

# %%
train_def.dtypes
# Out:
# index                    int64
# Unnamed: 0               int64
# Brand                   object
# Current Price          float64
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Model Name              object
# Dial Shape              object
# Strap Color             object
# Strap Material          object
# Touchscreen             object
# Battery Life (Days)    float64
# Bluetooth               object
# dtype: object

# %%
train_def.isnull().sum()
# Out:
# index                    0
# Unnamed: 0               0
# Brand                    0
# Current Price            6
# Original Price          56
# Discount Percentage     56
# Rating                   4
# Number OF Ratings       45
# Model Name              30
# Dial Shape             100
# Strap Color            100
# Strap Material          56
# Touchscreen             31
# Battery Life (Days)     30
# Bluetooth                5
# dtype: int64

# %%
train_def.info
# Out:
# <bound method DataFrame.info of      index  Unnamed: 0       Brand  Current Price  Original Price  \
# 0      407         407   zebronics         2949.0          4199.0
# 1      444         444  fire-boltt         6999.0         15999.0
# 2      117         117  fire-boltt         2499.0         11999.0
# 3       30          30        boat         1999.0          7990.0
# 4      415         415  fire-boltt         2299.0          5999.0
# ..     ...         ...         ...            ...             ...
# 355    216         216      fitbit        11699.0         14999.0
# 356    279         279      garmin        39490.0         44990.0
# 357    390         390   zebronics         2199.0          4999.0
# 358    337         337     gizmore         1199.0          4499.0
# 359    236         236      fitbit        20499.0             NaN
#
#      Discount Percentage  Rating  Number OF Ratings  \
# 0              29.768993     3.1               10.0
# ...

# %%
numerical_data = [feature for feature in train_def.columns if train_def[feature].dtype != 'object' ]

# %%
continuous_data = [feature for feature in train_def.columns if train_def[feature].dtype == 'object' ]

# %%
numerical_data, continuous_data
# Out:
# (['index',
#   'Unnamed: 0',
#   'Current Price',
#   'Original Price',
#   'Discount Percentage',
#   'Rating',
#   'Number OF Ratings',
#   'Battery Life (Days)'],
#  ['Brand',
#   'Model Name',
#   'Dial Shape',
#   'Strap Color',
#   'Strap Material',
#   'Touchscreen',
#   'Bluetooth'])

# %%
train_def[numerical_data].describe()
# Out:
#             index  Unnamed: 0  Current Price  Original Price  \
# count  360.000000  360.000000     354.000000      304.000000
# mean   222.702778  222.702778   12514.378531    14415.835526
# std    130.632905  130.632905   16914.978666    15613.457236
# min      0.000000    0.000000    1199.000000     1669.000000
# 25%    111.750000  111.750000    2126.000000     5999.000000
# 50%    222.500000  222.500000    3999.000000     7994.500000
# 75%    336.250000  336.250000   17367.250000    17996.000000
# max    448.000000  448.000000   98990.000000    96390.000000
#
#        Discount Percentage      Rating  Number OF Ratings  Battery Life (Days)
# count           304.000000  356.000000         315.000000           330.000000
# mean             47.955347    4.027528       10671.815873            14.181970
# std              24.696899    0.556828       27575.956948             7.661878
# min             -79.688436    1.000000           1.000000             0.750000
# ...

# %%
test_df[continuous_data].describe()
# Out:
#              Brand Model Name Dial Shape Strap Color Strap Material  \
# count           90         90         90          90             90
# unique           4         77          5          18              6
# top     fire-boltt       ring     Square       Black        Silicon
# freq            39          5         53          39             67
#
#        Touchscreen Bluetooth
# count           90        90
# unique           1         1
# top            Yes       Yes
# freq            90        90
